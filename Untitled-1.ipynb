# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv(r"D:\spl pro\1.Iris1.csv")
df=pd.DataFrame(data)
print(df)
fig=data[data.variety=='Setosa'].plot.scatter(x='petal.length',y='petal.width',color='orange',label="Setosa")
data[data.variety=='Vericolor'].plot.scatter(x='petal.length',y='petal.width',color='blue',label="versicolor",ax=fig)
data[data.variety=='viriginica'].plot.scatter(x='petal.length',y='petal.width',color='red',label="viriginica",ax=fig)
fig.set_xlabel("petal.length")
fig.set_ylabel("petal.width")
fig.set_title("petal length and width")
fig=plt.gcf()
fig.set_size_inches(8,8)
plt.show()
petal_width=data[data["petal.length"]==1.4]
print(petal_width)
count=data.groupby('petal.length')['petal.length'].count()
print(count)
sum=data['petal.length'].sum()
print(sum)
max=data['sepal.width'].max()
print(max)
add=data['sepal.length']+1.0
print(add)
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...
